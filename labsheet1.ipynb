# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudarshanksgowda/Data-Handling-and-Vizualization/blob/main/labsheet1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[4,5,6,7]
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line graph")
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[20,30,40,50]
y=["bananas","apples","dates","cherrries"]
z=["red","yellow","orange","green"]
a=[0,0,0,0.2]
plt.pie(x,labels=y,colors=z,explode=a)
plt.show()

# %%
import numpy as np
x=np.array(["a","b","c","d"])
y=np.array([2,4,3,1])
plt.bar(x,y)
plt.show()

# %%
plt.subplot(2,2,1)
x=[1,2,3,4]
y=[4,5,6,7]
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line graph")
plt.plot(x,y)


plt.subplot(2,2,2)
x=[20,30,40,50]
y=["bananas","apples","dates","cherries"]
c=["black","pink","yellow","blue"]
d=[0,0.2,0,0.1]
plt.pie(x,labels=y,colors=c,explode=d)


plt.subplot(2,2,3)
import numpy as np
x=np.array(["a","b","c","d"])
y=np.array([3,2.5,1,6])
z=["red","purple","green","orange"]
plt.bar(x,y,color=z)

plt.subplot(2,2,4)
x=[1,2,3,4,5]
y=[2,4,5,6,7]
colors=["r","y","b","g","b"]
sizes=[100,200,300,40,15]
plt.scatter(x,y,c=colors,s=sizes,alpha=0.9,marker="*",edgecolor="g")
plt.title("scatter",fontsize=20)
plt.xlabel("x axis",fontsize=20)
plt.ylabel("y axis",fontsize=20)
# Out:
# Text(0, 0.5, 'y axis')

# %%
plt.subplot(2,2,4)
x=[1,2,3,4,5]
y=[2,4,5,6,7]
colors=["r","y","b","g","b"]
sizes=[100,200,300,40,15]
plt.scatter(x,y,c=colors,s=sizes,alpha=0.9,marker="*",edgecolor="g")
plt.title("scatter",fontsize=20)
plt.xlabel("x axis",fontsize=20)
plt.ylabel("y axis",fontsize=20)
# Out:
# Text(0, 0.5, 'y axis')

# %%
import numpy as np
x=np.array(["a","b","c","d"])
y=np.array([3,2.5,1,6])
z=["red","purple","green","orange"]
plt.bar(x,y,color=z)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.subplot(2,2,2)
x=[20,30,40,50]
y=["bananas","apples","dates","cherries"]
c=["black","pink","yellow","blue"]
d=[0,0.2,0,0.1]
plt.pie(x,labels=y,colors=c,explode=d)
# Out:
# ([<matplotlib.patches.Wedge at 0x7d9aded5ff40>,
#   <matplotlib.patches.Wedge at 0x7d9aded46f20>,
#   <matplotlib.patches.Wedge at 0x7d9adeb94850>,
#   <matplotlib.patches.Wedge at 0x7d9adeb94cd0>],
#  [Text(0.9910657451172095, 0.47727213291294374, 'bananas'),
#   Text(-6.085739197947509e-08, 1.2999999999999985, 'apples'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'dates'),
#   Text(0.520660660470923, -1.081162557915313, 'cherries')])

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()
